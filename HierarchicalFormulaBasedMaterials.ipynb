# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import FormulaBasedMaterials as FBM
SFBM=FBM.SingleFormulaBasedMaterials(formula='sin(x)*cos(y)+sin(y)*cos(z)+sin(z)*cos(x)+1.5', png=False, smooth=True)

MFBM = FBM.MixFormulaBasedMaterials(rule='OR', unit='gyroid', eps=0.3, png=False)
MFBM.save2stl()
# Out:
# save stl model to gyroid_1x1x1_r0.1_OR
